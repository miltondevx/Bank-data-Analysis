# %% [markdown]
# ## summary
# * **Executed EDA on 3,000+ banking records using Python to identify customer behavioral patterns and demographic trends.**
#
# * **Engineered income-based customer segments to improve the precision of financial product targeting and risk profiling.**
#
# * **Built correlation heatmaps and distribution plots with Seaborn to translate complex banking metrics into actionable visual insights.**
#
# * **Mapped age and income trends against savings accumulation to pinpoint high-value segments for pension and investment products.**
#
# * **Quantified the relationship between bank deposits and savings activity to optimize liquidity management and customer retention.**
#
# * **Isolated business lending drivers from personal banking metrics to refine risk-mitigation and segmented debt strategies.**
#
# * **Automated data cleaning and preprocessing for 25 feature columns to ensure high-fidelity analysis of raw financial datasets.**
#
# * **Evaluated the impact of external market factors on property ownership to clarify why internal banking variables showed weak correlations.**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Banking-Dashboard/data/Banking.csv')
df.head()
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324  06-05-2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10-12-2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  25-01-2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  28-03-2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  20-07-2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
# shape of the DataFrame....
print("Shape of the DataFrame:", df.shape)

# summary of the DataFrame....
print("\nDataFrame Info:")
df.info()
# Out:
# Shape of the DataFrame: (3000, 25)
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
# ...

# %%
df["Estimated Income"]
# Out:
# 0        75384.77
# 1       289834.31
# 2       169935.23
# 3       356808.11
# 4       130711.68
#           ...
# 2995    297617.14
# 2996     42397.46
# 2997     48339.88
# 2998    107265.87
# 2999     56826.53
# Name: Estimated Income, Length: 3000, dtype: float64

# %%
# income band boundaries....
bins = [0, 100000, 300000, float('inf')]
labels = ['Low', 'Mid', 'High']

# Create the 'Income Band' column using pd.cut.....
df['Income Band'] = pd.cut(df['Estimated Income'], bins=bins, labels=labels, include_lowest=True)

# %%
# distribution of unique categories in categorical columns....
categorical_cols = df[["Risk Weighting","Nationality","Occupation","Fee Structure","Loyalty Classification","Properties Owned","Risk Weighting","Occupation","Income Band"]].columns
for col in categorical_cols:
  # if col in ["Client ID","Name","Joined Bank"]:
  #   continue
  print(f"\nValue Counts for '{col}':")
  display(df[col].value_counts())
# Out:
# Value Counts for 'Risk Weighting':
# Risk Weighting
# 2    1222
# 1     836
# 3     460
# 4     322
# 5     160
# Name: count, dtype: int64
# Value Counts for 'Nationality':
# Nationality
# European      1309
# Asian          754
# American       507
# Australian     254
# African        176
# Name: count, dtype: int64
# Value Counts for 'Occupation':
# Occupation
# Associate Professor             28
# Structural Analysis Engineer    28
# Recruiter                       25
# Account Coordinator             24
# Human Resources Manager         24
#                                 ..
# Office Assistant IV              8
# Automation Specialist I          7
# Computer Systems Analyst I       6
# Developer III                    5
# Senior Sales Associate           4
# Name: count, Length: 195, dtype: int64
# Value Counts for 'Fee Structure':
# Fee Structure
# High    1476
# Mid      962
# Low      562
# Name: count, dtype: int64
# Value Counts for 'Loyalty Classification':
# ...

# %%
# descriptive statistics for numerical columns.....
print("\nDescriptive Statistics for Numerical Columns:")
display(df.describe())
# Out:
# Descriptive Statistics for Numerical Columns:
#                Age   Location ID  Estimated Income  Superannuation Savings  \
# count  3000.000000   3000.000000       3000.000000             3000.000000
# mean     51.039667  21563.323000     171305.034263            25531.599673
# std      19.854760  12462.273017     111935.808209            16259.950770
# min      17.000000     12.000000      15919.480000             1482.030000
# 25%      34.000000  10803.500000      82906.595000            12513.775000
# 50%      51.000000  21129.500000     142313.480000            22357.355000
# 75%      69.000000  32054.500000     242290.305000            35464.740000
# max      85.000000  43369.000000     522330.260000            75963.900000
#
#        Amount of Credit Cards  Credit Card Balance    Bank Loans  \
# count             3000.000000          3000.000000  3.000000e+03
# mean                 1.463667          3176.206943  5.913862e+05
# ...

# %%
# missing values......
missing_values = df.isnull().sum()
print("Missing values per column:\n", missing_values)
# Out:
# Missing values per column:
#  Client ID                   0
# Name                        0
# Age                         0
# Location ID                 0
# Joined Bank                 0
# Banking Contact             0
# Nationality                 0
# Occupation                  0
# Fee Structure               0
# Loyalty Classification      0
# Estimated Income            0
# Superannuation Savings      0
# Amount of Credit Cards      0
# Credit Card Balance         0
# Bank Loans                  0
# Bank Deposits               0
# Checking Accounts           0
# Saving Accounts             0
# Foreign Currency Account    0
# Business Lending            0
# Properties Owned            0
# Risk Weighting              0
# BRId                        0
# GenderId                    0
# IAId                        0
# Income Band                 0
# dtype: int64

# %%
df['Joined Bank'] = pd.to_datetime(df['Joined Bank'], format='%d-%m-%Y')
print(df['Joined Bank'].dtype)
# Out:
# datetime64[ns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Numerical analysis and exploration.....
numerical_cols = ['Fee Structure','Age', 'Estimated Income', 'Superannuation Savings', 'Credit Card Balance', 'Bank Loans', 'Bank Deposits', 'Checking Accounts', 'Saving Accounts', 'Foreign Currency Account', 'Business Lending']

# Univariate analysis and visualization
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(4, 3, i + 1)
    sns.histplot(df[col], kde=True)
    plt.title(col)
plt.tight_layout()
plt.savefig('Bank-plt.png')
plt.show()

# %%
# numerical columns for correlation analysis.....
numerical_cols = ['Age', 'Estimated Income', 'Superannuation Savings', 'Credit Card Balance',
                  'Bank Loans', 'Bank Deposits', 'Checking Accounts', 'Saving Accounts',
                  'Foreign Currency Account', 'Business Lending', 'Properties Owned']

# correlation matrix......
correlation_matrix = df[numerical_cols].corr()

# heatmap of the correlation matrix...
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.savefig('Bank-heatmap.png')
plt.show()

# %%
pairs_to_plot = [
    ('Bank Deposits', 'Saving Accounts'),
    ('Checking Accounts', 'Saving Accounts'),
    ('Checking Accounts', 'Foreign Currency Account'),
    ('Age', 'Superannuation Savings'),
    ('Estimated Income', 'Checking Accounts'),
    ('Bank Loans', 'Credit Card Balance'),
    ('Business Lending', 'Bank Loans'),
]


for x_col, y_col in pairs_to_plot:
    plt.figure(figsize=(8, 6))
    sns.regplot(
        data=df,
        x=x_col,
        y=y_col,
        scatter_kws={'alpha': 0.4},     # semi-transparent points
        line_kws={'color': 'red'}       # best-fit line color
    )
    plt.title(f'Relationship between {x_col} and {y_col}', fontsize=14)
    plt.xlabel(x_col, fontsize=12)
    plt.ylabel(y_col, fontsize=12)
    plt.tight_layout()
    plt.savefig('pairs_to_plt.png')
    plt.show()

# %% [markdown]
# # Insights:

# %% [markdown]
# <h2>Deposits​‍​‌‍​‍‌​‍​‌‍​‍‌ and Savings Behavior</h2>The significant correlation between Bank Deposits and Saving Accounts implies that these could either be reflecting the same financial behavior (e.g. total amount of money a customer keeps in a bank) or that people who are active in depositing funds also are in the habit of maintaining or increasing savings balances.
#
# <h2> Income, Age, and Accumulation</h2>The moderate correlations of Age and Estimated Income with different balances (Superannuation, Savings, Checking) indicate a typical financial lifecycle trend which is: higher income earners and older people usually accumulate more savings and pension funds, and at the same time they may have higher credit card balances or loans.
#
# <h2>Low Correlation with Properties Owned</h2>The decision to own a property may be influenced by different factors (location, real estate market conditions, inheritance, etc.) which are not accounted for by these particular banking variables. That is why the correlations we see here are weaker.
#
# <h2>Business vs. Personal Banking</h2>The moderate connection of Business Lending to Bank Loans indicates that some customers may have both personal and business debts. Nevertheless, business lending shows very little correlation with other deposit or property-related metrics, thus, it may be catering to a distinct group of customers or different ​‍​‌‍​‍‌​‍​‌‍​‍‌needs.
